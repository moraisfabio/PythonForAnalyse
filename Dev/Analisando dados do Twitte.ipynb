# %%
#instalando o pacote twittepy
# !pip install tweepy
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# ...
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
#importando os modutos twettpy,Datetine, Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %%
#adicionando a consumer key
consumer_key = "KhgYyQkiJwmGBHHnHYWhIOCR1"

# %%
#adicionando sua consumer secret
consumer_secret = "jXuI6zDzzlUILGWwkIUBkpl03C3WMMnjCZ21yBDynfnzZ7dmUK"

# %%
#adicionando o acess token
acess_token = "2158998246-vS5V2c2Wa2rb9vUzyE86sC0m0Vl2onooX0UHiDg"

# %%
#adicionando o secret token
secret_token = "WUNn8jj7yb5CHQNjwz2rcFFoDo5biOjFmxTRDzR3q80c5"

# %%
#criando as chaves de autenticacao
authent = OAuthHandler(consumer_key,consumer_secret)

# %%
#setando a autenticacao
authent.set_access_token(acess_token,secret_token)

# %%
#criando uma classe para capturar os stream de dados do twitter
#e armazenar no mongodb
class Mydatas(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet['created_at']
        id_str = tweet['id_str']
        text = tweet['text']
        obj = {'created_at':created_at,'id_str':id_str,'text':text,}
        tweetind = col.insert_one(obj).inserted_id
        print(obj)
        return True

# %%
#criando o objeto
meusdados = Mydatas()

# %%
#criando objeto da stream
mystream = Stream(authent, listener = meusdados )

# %%
#importando do pymongo o cliente Clientmongo
from pymongo import MongoClient

# %%
#criando a conxexao com o mongodb
cliente = MongoClient()

# %%
#criando o banco de dados twetterdb
db = cliente.twitterdb

# %%
#criando a colexion que e comparado com uma coluna no banco relacional
col = db.tweets

# %%
#criando a lista de palavras chaves para buscar no tweeter
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %%
#coletando os tweets
#iniciando o filto e colocando no mongodb
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Tue Feb 26 01:42:04 +0000 2019', 'id_str': '1100209347542597633', 'text': 'RT @SPEtweets: Ridding science of shoddy #statistics will require scrutiny of every step, not merely the last one. #data #pvalue', '_id': ObjectId('5c7499719303fc0d73f4765a')}
# {'created_at': 'Tue Feb 26 01:42:04 +0000 2019', 'id_str': '1100209349421658112', 'text': 'A user-generated data based approach to enhancing location prediction of financial services in sub-Saharan Africa:… https://t.co/qloOr6x1BM', '_id': ObjectId('5c7499719303fc0d73f4765b')}
# {'created_at': 'Tue Feb 26 01:42:13 +0000 2019', 'id_str': '1100209386570559488', 'text': "i can't be the only one annoyed by all the deep learning python crap that isn't an exe file i can just run and do s… https://t.co/mtU72eZOiw", '_id': ObjectId('5c74997a9303fc0d73f4765c')}
# ...

# %%
#desconectando 
mystream.disconnect()

# %%
#verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5c7499719303fc0d73f4765a'),
#  'created_at': 'Tue Feb 26 01:42:04 +0000 2019',
#  'id_str': '1100209347542597633',
#  'text': 'RT @SPEtweets: Ridding science of shoddy #statistics will require scrutiny of every step, not merely the last one. #data #pvalue'}

# %%
#criando um dataset com os dados retornados do mongodb
dataset = [{'created_at':item['created_at'],'text':item['text'],} for item in col.find()]

# %%
#importando o modulo pandas para trablahar com datasets em python
import pandas as pd

# %%
#criando um datafrane a partir do dataset
df = pd.DataFrame(dataset)

# %%
#imprinindo o datafram
df
# Out:
#                         created_at  \
# 0   Tue Feb 26 01:42:04 +0000 2019
# 1   Tue Feb 26 01:42:04 +0000 2019
# 2   Tue Feb 26 01:42:13 +0000 2019
# 3   Tue Feb 26 01:42:14 +0000 2019
# 4   Tue Feb 26 01:42:15 +0000 2019
# 5   Tue Feb 26 01:42:15 +0000 2019
# 6   Tue Feb 26 01:42:15 +0000 2019
# 7   Tue Feb 26 01:42:19 +0000 2019
# 8   Tue Feb 26 01:42:24 +0000 2019
# 9   Tue Feb 26 01:42:25 +0000 2019
# 10  Tue Feb 26 01:42:27 +0000 2019
# 11  Tue Feb 26 01:42:28 +0000 2019
# 12  Tue Feb 26 01:42:31 +0000 2019
# 13  Tue Feb 26 01:42:32 +0000 2019
# 14  Tue Feb 26 01:42:33 +0000 2019
# 15  Tue Feb 26 01:42:34 +0000 2019
# 16  Tue Feb 26 01:42:36 +0000 2019
#
#                                                  text
# 0   RT @SPEtweets: Ridding science of shoddy #stat...
# 1   A user-generated data based approach to enhanc...
# 2   i can't be the only one annoyed by all the dee...
# 3   [FREE] – Python 3 na Web com Django (Básico e ...
# ...

# %%
#importanto o modulo scikit learn 
from sklearn.feature_extraction.text import CountVectorizer

# %%
#usando o metodo Vercotizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
#contanto o numero de ocorrencias das principais palavras no dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=['word'])
word_count['count'] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values('count', ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#            word  count
# 0           the     10
# 1          data     10
# 2            of     10
# 3         https     10
# 4            co      8
# 5            rt      8
# 6            to      6
# 7            in      5
# 8        python      4
# 9           big      4
# 10           it      4
# 11         with      3
# 12         only      3
# 13          all      3
# 14          can      3
# 15          for      3
# 16         time      3
# 17         like      3
# 18          and      3
# 19     facebook      2
# 20     football      2
# 21          say      2
# 22          one      2
# 23        every      2
# 24       others      2
# 25         free      2
# 26      science      2
# 27         sche      2
# 28         most      2
# 29           gt      2
# 30       mining      2
# 31         have      2
# 32         play      2
# 33  possessions      2
# 34           is      2
# 35         that      2
# 36          jan      2
# 37   johncusack      2
# 38           la      2
# ...
